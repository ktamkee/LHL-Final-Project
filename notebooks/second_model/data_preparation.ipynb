# %% [markdown]
# # Data Preparation

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %% [markdown]
# ## Europe

# %%
EUW1_matches = pd.read_csv('../../data/raw/EUW1_matches_180.csv')
EUW2_matches = pd.read_csv('../../data/raw/EUW2_matches_186.csv')
EUW_matches = pd.concat([EUW1_matches, EUW2_matches], axis=0)
EUW_matches = EUW_matches.drop_duplicates()
EUW_matches = EUW_matches.reset_index(drop=True)
# EUW_matches = EUW_matches.replace({'BLUE': 0, 'RED': 1, 'NONE':2})
# EUW_matches = EUW_matches.drop(columns=['MATCH_ID'])
EUW_matches.head()
# Out:
#         SERVER         MATCH_ID  \
# 0  EUROPE WEST  EUW1_6001811167
# 1  EUROPE WEST  EUW1_6001677114
# 2  EUROPE WEST  EUW1_6001722049
# 3  EUROPE WEST  EUW1_6001557446
# 4  EUROPE WEST  EUW1_6001602687
#
#                                             BSUM1_ID  BTOP_CHAMP_ID  \
# 0    0AZy9ZPtWQh6Vx8Kq7OvFy4UrZwrJACKWYJs-E6rzV4cizM            150
# 1    o02MjualoBd8c2L1Nu2ZRjnhkt_ne-Yx2iYRZkhd3uDKsY4            114
# 2    lz7z9m2ZwFuDm0kSa-6SYXtXLFTLLLlWizzRxSyCgh-Msk0            150
# 3    ZCHr8rokYRXJMJIUWzFcIehrJs6jShr0Zkc3aFJZ4xEiTfE             79
# 4  Yp9kCQ3SqtxY-dyRdyAm7i3zZgtduT21MlAjGPN_0NZ5tR...            122
#
#                                            BSUM2_ID  BJGL_CHAMP_ID  \
# 0  xh8g794rjw2i3e2OFWyH8NLvm9U94qaGNIAvSZUTDC9-BJRL            246
# 1   CaqfcvprY1V7DVI5sfOJP5Vc3luQoyshL8AemHrvh43qUQw            254
# 2   Gu0-dhJT1_53zm_TQt4BQ1uQ_CZhl4fHrN33OQG3cfz5teM             78
# 3   Gu0-dhJT1_53zm_TQt4BQ1uQ_CZhl4fHrN33OQG3cfz5teM             80
# ...

# %%
EUW_matches.shape
# Out:
# (366, 51)

# %%
EUW_pre_game_data = EUW_matches[['SERVER', 
       'BTOP_CHAMP_ID', 'BJGL_CHAMP_ID', 'BMID_CHAMP_ID', 'BBOT_CHAMP_ID', 'BSUP_CHAMP_ID', 
       'BBAN1', 'BBAN2', 'BBAN3', 'BBAN4', 'BBAN5', 
       'RTOP_CHAMP_ID', 'RJGL_CHAMP_ID', 'RMID_CHAMP_ID', 'RBOT_CHAMP_ID', 'RSUP_CHAMP_ID', 
       'RBAN1', 'RBAN2', 'RBAN3', 'RBAN4', 'RBAN5', 
       'WINNER']]

EUW_pre_game_data.head()
# Out:
#         SERVER  BTOP_CHAMP_ID  BJGL_CHAMP_ID  BMID_CHAMP_ID  BBOT_CHAMP_ID  \
# 0  EUROPE WEST            150            246            268             15
# 1  EUROPE WEST            114            254             79            498
# 2  EUROPE WEST            150             78            517            523
# 3  EUROPE WEST             79             80              4             18
# 4  EUROPE WEST            122             80            517             96
#
#    BSUP_CHAMP_ID  BBAN1  BBAN2  BBAN3  BBAN4  ...  RJGL_CHAMP_ID  \
# 0            497     62    107    119    114  ...             80
# 1            497    555     -1     -1    103  ...             78
# 2            888    432    119    555     55  ...            234
# 3            235    517     20    350    122  ...              2
# 4            432     67    350     20     29  ...            421
#
#    RMID_CHAMP_ID  RBOT_CHAMP_ID  RSUP_CHAMP_ID  RBAN1  RBAN2  RBAN3  RBAN4  \
# ...

# %%
EUW_mid_game_data = EUW_matches[['SERVER', 
       'BTOP_CHAMP_ID', 'BJGL_CHAMP_ID', 'BMID_CHAMP_ID', 'BBOT_CHAMP_ID', 'BSUP_CHAMP_ID', 
       'BBAN1', 'BBAN2', 'BBAN3', 'BBAN4', 'BBAN5', 
       'RTOP_CHAMP_ID', 'RJGL_CHAMP_ID', 'RMID_CHAMP_ID', 'RBOT_CHAMP_ID', 'RSUP_CHAMP_ID', 
       'RBAN1', 'RBAN2', 'RBAN3', 'RBAN4', 'RBAN5', 
       'FIRST_BLOOD', 'FIRST_DRAG', 'FIRST_HERALD', 'FIRST_TOWER', 
       'WINNER']]

EUW_mid_game_data.head()
# Out:
#         SERVER  BTOP_CHAMP_ID  BJGL_CHAMP_ID  BMID_CHAMP_ID  BBOT_CHAMP_ID  \
# 0  EUROPE WEST            150            246            268             15
# 1  EUROPE WEST            114            254             79            498
# 2  EUROPE WEST            150             78            517            523
# 3  EUROPE WEST             79             80              4             18
# 4  EUROPE WEST            122             80            517             96
#
#    BSUP_CHAMP_ID  BBAN1  BBAN2  BBAN3  BBAN4  ...  RBAN1  RBAN2  RBAN3  RBAN4  \
# 0            497     62    107    119    114  ...    350    119    777     78
# 1            497    555     -1     -1    103  ...    157    432    777    119
# 2            888    432    119    555     55  ...     92    117     62    103
# 3            235    517     20    350    122  ...    517    421     67    119
# 4            432     67    350     20     29  ...     39    200     78    119
#
# ...

# %%
# EUW_matches.to_csv('EUW_all_data_366.csv', index=False)
# EUW_mid_game_data.to_csv('EUW_mid_game_data_366.csv', index=False)
# EUW_pre_game_data.to_csv('EUW_pre_game_data_366.csv', index=False)

# %% [markdown]
# ## North America

# %%
NA1_matches = pd.read_csv('../../data/raw/NA1_matches_192.csv')
NA2_matches = pd.read_csv('../../data/raw/NA2_matches_196.csv')
NA_matches = pd.concat([NA1_matches, NA2_matches], axis=0)
NA_matches = NA_matches.drop_duplicates()
NA_matches = NA_matches.reset_index(drop=True)
# NA_matches = NA_matches.replace({'BLUE': 0, 'RED': 1, 'NONE':2})
# NA_matches = NA_matches.drop(columns=['MATCH_ID'])
NA_matches.head()
# Out:
#           SERVER        MATCH_ID  \
# 0  NORTH AMERICA  NA1_4396515853
# 1  NORTH AMERICA  NA1_4396540388
# 2  NORTH AMERICA  NA1_4396495283
# 3  NORTH AMERICA  NA1_4396437949
# 4  NORTH AMERICA  NA1_4396434056
#
#                                           BSUM1_ID  BTOP_CHAMP_ID  \
# 0  _rz2B5gcGgG78Ce-qPHbK_BjSGuAYXVbU5HehuD69QhJE2I             50
# 1  r0VX6FfhshlR1S_yFNnv3FZ24b37EPCXZ0X5PUpu82Mqncs            266
# 2  g96u4Zu60wNHE_ghxcPDuC_Mc9ouc3m48Mx_NLdZ1FMdfxg            266
# 3  Mj8iPiDSI3xHQO_1gDFsGz5uf6dwY7vHZla08rzzMuRmHYc             27
# 4  daODRa4nnhTu0q1-eycLcvTqE_eG9-knakaOpTdDwymGsD0            516
#
#                                            BSUM2_ID  BJGL_CHAMP_ID  \
# 0   RWNELKaFziEInyoYrBUt2CAKeHxIi_1S71GwvUdr__CJErI            200
# 1   qxox9oRsNSZttfe03EJKZgf5_YV7eqYl5SbsSuioeY0zlF8              9
# 2   Dr8A8hpa5aBnlkY4qMoo8d40qEcqOIIlfc0C3ojR4JGkJmQ            200
# 3  H9lyL4tk2OM82hgYSU36Dr-MlVdpGFY7OBQ45cQSnP0jKzNh            421
# ...

# %%
NA_matches.shape
# Out:
# (379, 51)

# %%
NA_pre_game_data = NA_matches[['SERVER', 
       'BTOP_CHAMP_ID', 'BJGL_CHAMP_ID', 'BMID_CHAMP_ID', 'BBOT_CHAMP_ID', 'BSUP_CHAMP_ID', 
       'BBAN1', 'BBAN2', 'BBAN3', 'BBAN4', 'BBAN5', 
       'RTOP_CHAMP_ID', 'RJGL_CHAMP_ID', 'RMID_CHAMP_ID', 'RBOT_CHAMP_ID', 'RSUP_CHAMP_ID', 
       'RBAN1', 'RBAN2', 'RBAN3', 'RBAN4', 'RBAN5', 
       'WINNER']]

NA_pre_game_data.head()
# Out:
#           SERVER  BTOP_CHAMP_ID  BJGL_CHAMP_ID  BMID_CHAMP_ID  BBOT_CHAMP_ID  \
# 0  NORTH AMERICA             50            200             38            119
# 1  NORTH AMERICA            266              9              8            119
# 2  NORTH AMERICA            266            200              1            360
# 3  NORTH AMERICA             27            421             74            119
# 4  NORTH AMERICA            516            131            104            523
#
#    BSUP_CHAMP_ID  BBAN1  BBAN2  BBAN3  BBAN4  ...  RJGL_CHAMP_ID  \
# 0            555    350    266    147    888  ...            203
# 1            875    888     84    114    147  ...            421
# 2            113    246     55    238     91  ...             78
# 3            111     35    350    268    103  ...            238
# 4             43    200    221    203    266  ...            238
#
#    RMID_CHAMP_ID  RBOT_CHAMP_ID  RSUP_CHAMP_ID  RBAN1  RBAN2  RBAN3  RBAN4  \
# ...

# %%
NA_mid_game_data = NA_matches[['SERVER', 
       'BTOP_CHAMP_ID', 'BJGL_CHAMP_ID', 'BMID_CHAMP_ID', 'BBOT_CHAMP_ID', 'BSUP_CHAMP_ID', 
       'BBAN1', 'BBAN2', 'BBAN3', 'BBAN4', 'BBAN5', 
       'RTOP_CHAMP_ID', 'RJGL_CHAMP_ID', 'RMID_CHAMP_ID', 'RBOT_CHAMP_ID', 'RSUP_CHAMP_ID', 
       'RBAN1', 'RBAN2', 'RBAN3', 'RBAN4', 'RBAN5', 
       'FIRST_BLOOD', 'FIRST_DRAG', 'FIRST_HERALD', 'FIRST_TOWER', 
       'WINNER']]

NA_mid_game_data.head()
# Out:
#           SERVER  BTOP_CHAMP_ID  BJGL_CHAMP_ID  BMID_CHAMP_ID  BBOT_CHAMP_ID  \
# 0  NORTH AMERICA             50            200             38            119
# 1  NORTH AMERICA            266              9              8            119
# 2  NORTH AMERICA            266            200              1            360
# 3  NORTH AMERICA             27            421             74            119
# 4  NORTH AMERICA            516            131            104            523
#
#    BSUP_CHAMP_ID  BBAN1  BBAN2  BBAN3  BBAN4  ...  RBAN1  RBAN2  RBAN3  RBAN4  \
# 0            555    350    266    147    888  ...     24    360     84     53
# 1            875    888     84    114    147  ...    203     11    350    777
# 2            113    246     55    238     91  ...     30    888    157     67
# 3            111     35    350    268    103  ...    235     84    246    555
# 4             43    200    221    203    266  ...    157    888    200    246
#
# ...

# %%
# NA_matches.to_csv('NA_all_data_379.csv', index=False)
# NA_mid_game_data.to_csv('NA_mid_game_data_379.csv', index=False)
# NA_pre_game_data.to_csv('NA_pre_game_data_379.csv', index=False)

# %% [markdown]
# ## Korea

# %%
KR1_matches = pd.read_csv('../../data/raw/KR1_matches_183.csv')
KR2_matches = pd.read_csv('../../data/raw/KR2_matches_215.csv')
KR_matches = pd.concat([KR1_matches, KR2_matches], axis=0)
KR_matches = KR_matches.drop_duplicates()
KR_matches = KR_matches.reset_index(drop=True)
# KR_matches = KR_matches.replace({'BLUE': 0, 'RED': 1, 'NONE':2})
# KR_matches = KR_matches.drop(columns=['MATCH_ID'])
KR_matches.head()
# Out:
#   SERVER       MATCH_ID                                           BSUM1_ID  \
# 0  KOREA  KR_6057844675  sbDHeqqUvLDhNA3yYnS3t93fG4d9doqldZjOkb3rwrybN_...
# 1  KOREA  KR_6055710166    TOvKujDuw_rTCUebjSXidH8OJf_IoReR-YNkEDRhF-xCoOA
# 2  KOREA  KR_6055326646    vw7N9YLAgtt3OEuzBHDzq7gQjIcdhK-crpvGNdbm7co2dck
# 3  KOREA  KR_6053723720    5A4WJpFsCzkRoVDHzNAVO6bre5LRlLSlu5bDjX2oBOs9qKE
# 4  KOREA  KR_6053619349    q3wZkwddVzV3gqDEZuE7l65m8U0j40aFprEdroCXXRyFXi0
#
#    BTOP_CHAMP_ID                                           BSUM2_ID  \
# 0             59  3PV_W4RY09TzgEQfBZNdSlsHFwxjwbjzIwXsawLuoSVYyp...
# 1            266    8K1yx07pCws-gzQxIzqyuoyVtEGbaUk35YQDtbEyoFgIA2Y
# 2             29    EV23s0Fe5ptC8cyk1148besP5YnAtguSS9golPxZRwvwEyo
# 3            113  MDqGtPmXx3f2LMeKFTuWuI53bD4usXQCxyua869BLnh8Wx...
# 4             14  Tx5p5q4af3CF8ckXbeZCZk4-RD8WepIX3KU1NzF5BS5swQ...
#
#    BJGL_CHAMP_ID                                          BSUM3_ID  \
# ...

# %%
KR_matches.shape
# Out:
# (358, 51)

# %%
KR_pre_game_data = KR_matches[['SERVER', 
       'BTOP_CHAMP_ID', 'BJGL_CHAMP_ID', 'BMID_CHAMP_ID', 'BBOT_CHAMP_ID', 'BSUP_CHAMP_ID', 
       'BBAN1', 'BBAN2', 'BBAN3', 'BBAN4', 'BBAN5', 
       'RTOP_CHAMP_ID', 'RJGL_CHAMP_ID', 'RMID_CHAMP_ID', 'RBOT_CHAMP_ID', 'RSUP_CHAMP_ID', 
       'RBAN1', 'RBAN2', 'RBAN3', 'RBAN4', 'RBAN5', 
       'WINNER']]

KR_pre_game_data.head()
# Out:
#   SERVER  BTOP_CHAMP_ID  BJGL_CHAMP_ID  BMID_CHAMP_ID  BBOT_CHAMP_ID  \
# 0  KOREA             59             60            777            157
# 1  KOREA            266            234            103             15
# 2  KOREA             29             62            888            887
# 3  KOREA            113             80            711            523
# 4  KOREA             14             64            711            221
#
#    BSUP_CHAMP_ID  BBAN1  BBAN2  BBAN3  BBAN4  ...  RJGL_CHAMP_ID  \
# 0            254    887     91    163     -1  ...            234
# 1             50    517    350    221    429  ...              5
# 2            517     86     68    895     78  ...             80
# 3            888    429    163     -1     -1  ...             78
# 4            888    429    895     -1     -1  ...             91
#
#    RMID_CHAMP_ID  RBOT_CHAMP_ID  RSUP_CHAMP_ID  RBAN1  RBAN2  RBAN3  RBAN4  \
# 0             58            221            350    236     -1     15    429
# ...

# %%
KR_mid_game_data = KR_matches[['SERVER', 
       'BTOP_CHAMP_ID', 'BJGL_CHAMP_ID', 'BMID_CHAMP_ID', 'BBOT_CHAMP_ID', 'BSUP_CHAMP_ID', 
       'BBAN1', 'BBAN2', 'BBAN3', 'BBAN4', 'BBAN5', 
       'RTOP_CHAMP_ID', 'RJGL_CHAMP_ID', 'RMID_CHAMP_ID', 'RBOT_CHAMP_ID', 'RSUP_CHAMP_ID', 
       'RBAN1', 'RBAN2', 'RBAN3', 'RBAN4', 'RBAN5', 
       'FIRST_BLOOD', 'FIRST_DRAG', 'FIRST_HERALD', 'FIRST_TOWER', 
       'WINNER']]

KR_mid_game_data.head()
# Out:
#   SERVER  BTOP_CHAMP_ID  BJGL_CHAMP_ID  BMID_CHAMP_ID  BBOT_CHAMP_ID  \
# 0  KOREA             59             60            777            157
# 1  KOREA            266            234            103             15
# 2  KOREA             29             62            888            887
# 3  KOREA            113             80            711            523
# 4  KOREA             14             64            711            221
#
#    BSUP_CHAMP_ID  BBAN1  BBAN2  BBAN3  BBAN4  ...  RBAN1  RBAN2  RBAN3  RBAN4  \
# 0            254    887     91    163     -1  ...    236     -1     15    429
# 1             50    517    350    221    429  ...    895    246    107    163
# 2            517     86     68    895     78  ...     -1     -1    268     92
# 3            888    429    163     -1     -1  ...     -1    887     15    119
# 4            888    429    895     -1     -1  ...     78     58     -1    119
#
#    RBAN5  FIRST_BLOOD  FIRST_DRAG  FIRST_HERALD  FIRST_TOWER  WINNER
# ...

# %%
# KR_matches.to_csv('KR_all_data_358.csv', index=False)
# KR_mid_game_data.to_csv('KR_mid_game_data_358.csv', index=False)
# KR_pre_game_data.to_csv('KR_pre_game_data_358.csv', index=False)

# %% [markdown]
# ## Complete Dataset

# %%
all_games = pd.concat([EUW_matches, KR_matches , NA_matches], axis=0)
all_games = all_games.replace({'BLUE': 0, 'RED': 1, 'NONE':2})
all_games = all_games.drop(columns=['MATCH_ID'])
all_games.head()
# Out:
#         SERVER                                           BSUM1_ID  \
# 0  EUROPE WEST    0AZy9ZPtWQh6Vx8Kq7OvFy4UrZwrJACKWYJs-E6rzV4cizM
# 1  EUROPE WEST    o02MjualoBd8c2L1Nu2ZRjnhkt_ne-Yx2iYRZkhd3uDKsY4
# 2  EUROPE WEST    lz7z9m2ZwFuDm0kSa-6SYXtXLFTLLLlWizzRxSyCgh-Msk0
# 3  EUROPE WEST    ZCHr8rokYRXJMJIUWzFcIehrJs6jShr0Zkc3aFJZ4xEiTfE
# 4  EUROPE WEST  Yp9kCQ3SqtxY-dyRdyAm7i3zZgtduT21MlAjGPN_0NZ5tR...
#
#    BTOP_CHAMP_ID                                          BSUM2_ID  \
# 0            150  xh8g794rjw2i3e2OFWyH8NLvm9U94qaGNIAvSZUTDC9-BJRL
# 1            114   CaqfcvprY1V7DVI5sfOJP5Vc3luQoyshL8AemHrvh43qUQw
# 2            150   Gu0-dhJT1_53zm_TQt4BQ1uQ_CZhl4fHrN33OQG3cfz5teM
# 3             79   Gu0-dhJT1_53zm_TQt4BQ1uQ_CZhl4fHrN33OQG3cfz5teM
# 4            122   Gu0-dhJT1_53zm_TQt4BQ1uQ_CZhl4fHrN33OQG3cfz5teM
#
#    BJGL_CHAMP_ID                                           BSUM3_ID  \
# 0            246   9T_e3hPA8BJJkJ-VGvGVJWR24xPZ0yyY5aGTOIKl95Cd6h8g
# ...

# %%
all_games.shape
# Out:
# (1103, 50)

# %%
all_pre_game_data = all_games[['SERVER', 
       'BTOP_CHAMP_ID', 'BJGL_CHAMP_ID', 'BMID_CHAMP_ID', 'BBOT_CHAMP_ID', 'BSUP_CHAMP_ID', 
       'BBAN1', 'BBAN2', 'BBAN3', 'BBAN4', 'BBAN5', 
       'RTOP_CHAMP_ID', 'RJGL_CHAMP_ID', 'RMID_CHAMP_ID', 'RBOT_CHAMP_ID', 'RSUP_CHAMP_ID', 
       'RBAN1', 'RBAN2', 'RBAN3', 'RBAN4', 'RBAN5', 
       'WINNER']]

all_pre_game_data.head()
# Out:
#         SERVER  BTOP_CHAMP_ID  BJGL_CHAMP_ID  BMID_CHAMP_ID  BBOT_CHAMP_ID  \
# 0  EUROPE WEST            150            246            268             15
# 1  EUROPE WEST            114            254             79            498
# 2  EUROPE WEST            150             78            517            523
# 3  EUROPE WEST             79             80              4             18
# 4  EUROPE WEST            122             80            517             96
#
#    BSUP_CHAMP_ID  BBAN1  BBAN2  BBAN3  BBAN4  ...  RJGL_CHAMP_ID  \
# 0            497     62    107    119    114  ...             80
# 1            497    555     -1     -1    103  ...             78
# 2            888    432    119    555     55  ...            234
# 3            235    517     20    350    122  ...              2
# 4            432     67    350     20     29  ...            421
#
#    RMID_CHAMP_ID  RBOT_CHAMP_ID  RSUP_CHAMP_ID  RBAN1  RBAN2  RBAN3  RBAN4  \
# ...

# %%
all_mid_game_data = all_games[['SERVER', 
       'BTOP_CHAMP_ID', 'BJGL_CHAMP_ID', 'BMID_CHAMP_ID', 'BBOT_CHAMP_ID', 'BSUP_CHAMP_ID', 
       'BBAN1', 'BBAN2', 'BBAN3', 'BBAN4', 'BBAN5', 
       'RTOP_CHAMP_ID', 'RJGL_CHAMP_ID', 'RMID_CHAMP_ID', 'RBOT_CHAMP_ID', 'RSUP_CHAMP_ID', 
       'RBAN1', 'RBAN2', 'RBAN3', 'RBAN4', 'RBAN5', 
       'FIRST_BLOOD', 'FIRST_DRAG', 'FIRST_HERALD', 'FIRST_TOWER', 
       'WINNER']]

all_mid_game_data.head()
# Out:
#         SERVER  BTOP_CHAMP_ID  BJGL_CHAMP_ID  BMID_CHAMP_ID  BBOT_CHAMP_ID  \
# 0  EUROPE WEST            150            246            268             15
# 1  EUROPE WEST            114            254             79            498
# 2  EUROPE WEST            150             78            517            523
# 3  EUROPE WEST             79             80              4             18
# 4  EUROPE WEST            122             80            517             96
#
#    BSUP_CHAMP_ID  BBAN1  BBAN2  BBAN3  BBAN4  ...  RBAN1  RBAN2  RBAN3  RBAN4  \
# 0            497     62    107    119    114  ...    350    119    777     78
# 1            497    555     -1     -1    103  ...    157    432    777    119
# 2            888    432    119    555     55  ...     92    117     62    103
# 3            235    517     20    350    122  ...    517    421     67    119
# 4            432     67    350     20     29  ...     39    200     78    119
#
# ...

# %%
# all_games.to_csv('all_games_1103.csv', index=False)
# all_pre_game_data.to_csv('all_pre_game_data_1103.csv', index=False)
# all_mid_game_data.to_csv('all_mid_game_data_1103.csv', index=False)
